# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x=np.linspace(0.,10.,200)
y=np.sin(x)
plt.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.plot(x,y, label="okk")
fig.legend()

ax.grid()
